# %%
# Import widget library
import ipywidgets as widgets

# %%
# Creating a random slider
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
# You can explicitly import the display library
from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
# Displaying the same widget instance will yield coordinated movement
display(w)
# Out:
# IntSlider(value=0)

# %%
# Can either obtain the value or set the value
w.value = 99

# %%
# The different 'settings' for the widget
w.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
# Sets step size
w.step = 1
# Sets the max value for the slider
w.max = 10
# Sets the minimum value for the slider
w.min = -10

# %%
widgets.Text(value = 'Hello', disabled = False)
# Out:
# Text(value='Hello')

# %%
# Linking two different widgets together
a = widgets.FloatText()
b = widgets.FloatSlider()
display(a,b)

mylink = widgets.jslink((a, 'value'), (b, 'value'))
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)

# %%
# unlinking
mylink.unlink()

# %%
# IntRangeSlider
widgets.IntRangeSlider(
    value=[5, 7],
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d',
)
# Out:
# IntRangeSlider(value=(5, 7), continuous_update=False, description='Test:', max=10)

# %%
# IntProgressSlider
widgets.IntProgress(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Loading:',
    bar_style='', # 'success', 'info', 'warning', 'danger' or ''
    orientation='horizontal'
)
# Out:
# IntProgress(value=7, description='Loading:', max=10)

# %%
# BoundedIntText
widgets.BoundedIntText(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Text:',
    disabled=False
)
# Out:
# BoundedIntText(value=7, description='Text:', max=10)

# %%
# FloatText
widgets.FloatText(
    value=7.5,
    description='Any:',
    disabled=False
)
# Out:
# FloatText(value=7.5, description='Any:')

# %%
# Toggle Button
w = widgets.ToggleButton(
    value=False,
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check'
)
display(w)
# Out:
# ToggleButton(value=False, description='Click me', icon='check', tooltip='Description')

# %%
w.value
# Out:
# False

# %%
# Valid
widgets.Valid(
    value=False,
    description='Valid?',
)
# Out:
# Valid(value=False, description='Valid?')

# %%
# Dropdown
widgets.Dropdown(
    options=['1', '2', '3'],
    value='2',
    description='Number:',
    disabled=False,
)
# Out:
# Dropdown(description='Number:', index=1, options=('1', '2', '3'), value='2')

# %%
# Dropdown with string choices but returns numbers
widgets.Dropdown(
    options=[('One', 1), ('Two', 2), ('Three', 3)],
    value=2,
    description='Number:',
)
# Out:
# Dropdown(description='Number:', index=1, options=(('One', 1), ('Two', 2), ('Three', 3)), value=2)

# %%
# Radio Buttons
b = widgets.RadioButtons(
    options=['pepperoni', 'pineapple', 'anchovies'],
#     value='pineapple',
    description='Pizza topping:',
    disabled=False
)
display(b)
# Out:
# RadioButtons(description='Pizza topping:', options=('pepperoni', 'pineapple', 'anchovies'), value='pepperoni')

# %%
b.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_options_labels',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'index',
#  'layout',
#  'style']

# %%
s = widgets.Select(
    options=['Linux', 'Windows', 'OSX'],
    value='OSX',
    # rows=10,
    description='OS:',
    disabled=False
)
display(s)
# Out:
# Select(description='OS:', index=2, options=('Linux', 'Windows', 'OSX'), value='OSX')

# %%
s.value
# Out:
# 'Windows'

# %%
s.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_options_labels',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'index',
#  'layout',
#  'rows',
#  'style']

# %%
widgets.SelectionSlider(
    options=['scrambled', 'sunny side up', 'poached', 'over easy'],
    value='sunny side up',
    description='I like my eggs ...',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True
)
# Out:
# SelectionSlider(continuous_update=False, description='I like my eggs ...', index=1, options=('scrambled', 'sun…

# %%
widgets.ToggleButtons(
    options=['Slow', 'Regular', 'Fast'],
    description='Speed:',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=['Description of slow', 'Description of regular', 'Description of fast'],
    # icons=['check'] * 3
)
# Out:
# ToggleButtons(description='Speed:', options=('Slow', 'Regular', 'Fast'), tooltips=('Description of slow', 'Des…

# %%
# Allows you to select multiple!
m = widgets.SelectMultiple(
    options=['Apples', 'Oranges', 'Pears'],
    value=['Oranges'],
    #rows=10,
    description='Fruits',
    disabled=False
)
display(m)
# Out:
# SelectMultiple(description='Fruits', index=(1,), options=('Apples', 'Oranges', 'Pears'), value=('Oranges',))

# %%
m.value[0]
# Out:
# 'Apples'

# %%
widgets.HBox([widgets.Label(value="The $m$ in $E=mc^2$:"), widgets.FloatSlider()])

# %%
widgets.HTML(
    value="What the <b>flip</b> is <i>UP</i>",
    placeholder='Some HTML',
    description='Some HTML',
)
# Out:
# HTML(value='What the <b>flip</b> is <i>UP</i>', description='Some HTML', placeholder='Some HTML')

# %%
widgets.Button(
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check'
)
# Out:
# Button(description='Click me', icon='check', style=ButtonStyle(), tooltip='Click me')

# %%
play = widgets.Play(
    #interval=10,
    value=50,
    min=0,
    max=100,
    step=1,
    description="Press play",
    disabled=False
)
slider = widgets.IntSlider()
widgets.jslink((play, 'value'), (slider, 'value'))
widgets.HBox([play, slider])

# %%
widgets.ColorPicker(
    concise=False,
    description='Pick a color',
    value='blue',
    disabled=False
)
# Out:
# ColorPicker(value='blue', description='Pick a color')

# %% [markdown]
# ### CLEANING DATA

# %%
import pandas as pd

# %%
voter_data = pd.read_csv("./data/county_facts.csv")
primary_res = pd.read_csv("./data/primary_results.csv")

# %%
primary_res = primary_res.drop(columns=['fips', 'fraction_votes']).groupby(['state_abbreviation', 'party']).sum()

# %%
primary_res['votes'] = primary_res['votes']/3442623

# %%
primary_res['votes'] = primary_res['votes'] * 10000

# %%
# how many people per state would vote dem/rep
primary_res = primary_res.round({'votes': 0})
primary_res.to_csv(r"./data/primary_clean.csv")

# %%
voter_data = voter_data.groupby('state_abbreviation').mean().rename(columns={"PST045214": "Population", "AGE775214": "65 Yr+", "SEX255214": "Female", "RHI125214":"White", "RHI225214":"Black/African American",  "RHI325214":"American Indian/Alaskan Native",  "RHI425214":"Asian",  "RHI525214":"Native Hawaiian/Pacific Islander",  "RHI625214":"Two or More Races",  "RHI725214":"Hispanic/Latino",  "RHI825214":"White alone/Not Hispanic or Latino", "POP645213":"Foreign-born", "EDU635213":"High School Graduate or Higher", "EDU685213":"Bachelors Degree or Higher", "VET605213":"Veterans", "INC110213":"Median Household Income", "PVY020213":"Persons Living Below Poverty Level"}).drop(columns=['fips', 'PST040210','PST120214','POP010210','POP715213','POP815213','LFE305213','HSG010214','HSG445213','HSG096213','HSG495213','HSD410213','HSD310213','INC910213','BZA010213','BZA110213','BZA115213','NES010213','SBO001207','SBO315207','SBO115207','SBO215207','SBO515207','SBO415207','SBO015207','MAN450207','WTN220207','RTN130207','RTN131207','AFN120207','BPS030214','LND110210','POP060210']).rename(columns={"AGE295214":"Under 18"}).drop(columns=['AGE135214'])

# %%
voter_data['Veterans'] = voter_data['Veterans']/voter_data['Population']

# %%
voter_data = voter_data.drop(columns=['Population'])

# %%
voter_data.round(0)
# Out:
#                     65 Yr+  Female  White  Black/African American  \
# state_abbreviation
# AK                    10.0    46.0   53.0                     2.0
# AL                    17.0    51.0   68.0                    29.0
# AR                    18.0    51.0   80.0                    16.0
# AZ                    19.0    50.0   79.0                     2.0
# CA                    16.0    50.0   82.0                     4.0
# CO                    17.0    48.0   93.0                     2.0
# CT                    16.0    51.0   86.0                     8.0
# DC                    11.0    53.0   44.0                    49.0
# DE                    18.0    52.0   73.0                    21.0
# FL                    20.0    49.0   81.0                    15.0
# GA                    16.0    50.0   68.0                    28.0
# HI                    19.0    50.0   31.0                     1.0
# IA                    19.0    50.0   96.0                     1.0
# ...

# %%
voting_age = 100 - voter_data['Under 18']
voting_age
# Out:
# state_abbreviation
# AK    75.720690
# AL    77.620896
# AR    77.297333
# AZ    76.153333
# CA    77.482759
# CO    79.128125
# CT    79.412500
# DC    82.500000
# DE    78.233333
# FL    80.161194
# GA    76.729560
# HI    82.380000
# IA    77.019192
# ID    74.629545
# IL    78.196078
# IN    76.620652
# KS    76.172381
# KY    77.351667
# LA    76.017188
# MA    80.257143
# MD    78.220833
# ME    80.868750
# MI    79.562651
# MN    76.963218
# MO    77.197391
# MS    76.018293
# MT    78.387500
# NC    78.535000
# ND    77.507547
# NE    76.911828
# NH    80.880000
# NJ    77.738095
# NM    77.436364
# NV    78.523529
# NY    79.312903
# OH    77.098864
# OK    75.887013
# OR    79.088889
# PA    79.843284
# RI    80.680000
# SC    77.986957
# SD    75.060606
# TN    78.180000
# TX    75.673228
# UT    70.093103
# VA    79.594776
# VT    80.507143
# WA    78.125641
# WI    78.348611
# WV    79.818182
# WY    76.991304
# Name: Under 18, dtype: float64

# %%
voter_data['Of Voting Age'] = voting_age

# %%
voter_data = voter_data.drop(columns=['Under 18']).round(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-ba8dd8ad782f> in <module>
# ----> 1 voter_data = voter_data.drop(columns=['Under 18']).round(0)
#       2 voter_data
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
voter_data.to_csv(r'./data/county_clean.csv')

# %%
pd.merge(primary_res, voter_data, on="state_abbreviation", how='right')
# Out:
#                            votes     65 Yr+     Female      White  \
# state_abbreviation
# AK                      1.565667  10.282759  45.731034  52.510345
# AK                     63.701428  10.282759  45.731034  52.510345
# AL                   1122.187936  16.935821  51.262687  68.264179
# AL                   2433.121489  16.935821  51.262687  68.264179
# AR                    608.396563  18.336000  50.541333  80.406667
# AR                   1151.804888  18.336000  50.541333  80.406667
# AZ                   1159.281745  18.973333  49.633333  78.986667
# AZ                   1263.870601  18.973333  49.633333  78.986667
# CA                  10000.000000  15.965517  49.517241  81.594828
# CA                   4344.286319  15.965517  49.517241  81.594828
# CO                    352.010662  17.226562  48.045313  92.618750
# CT                    936.742129  15.800000  50.812500  85.775000
# CT                    606.563658  15.800000  50.812500  85.775000
# ...
